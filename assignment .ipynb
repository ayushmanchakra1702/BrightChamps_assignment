# %% [markdown]
# # Importing all the libraries required

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df0 = pd.read_csv('df0.csv')

# %%
df0
# Out:
#                             Email  Employee ID  First Name  Last Name  City  \
# 0         john.storm@gotrocks.net         9345         NaN        NaN   NaN
# 1          john.johnson@wahoo.com         6875         NaN        NaN   NaN
# 2        debby.powers@jeemail.com         6431         NaN        NaN   NaN
# 3      joe.byethen@whitehouse.gov         6076         NaN        NaN   NaN
# 4          stephanie.diaz@msm.org         8198         NaN        NaN   NaN
# 5           donald.gump@wahoo.com         7220         NaN        NaN   NaN
# 6        sarah.cohen@coldmail.com         8638         NaN        NaN   NaN
# 7  vladimir.lupin@kremlinmail.com         8187         NaN        NaN   NaN
#
#    Hire Date  Hiring Year  Payroll  Payroll Raise %  Raise Payroll
# 0        NaN          NaN  £10,088              NaN            NaN
# 1        NaN          NaN  £11,176              NaN            NaN
# 2        NaN          NaN  £10,546              NaN            NaN
# ...

# %%
df1 = pd.read_csv('df1.csv')

# %%
df1
# Out:
#                             Email   Hire date        City
# 0          john.johnson@wahoo.com   1-19-2019  Manchester
# 1        debby.powers@jeemail.com   9-21-2018     Cardiff
# 2        sarah.cohen@coldmail.com  11-16-2018  Birmingham
# 3              liza.olson@owl.com  11-06-2017   Liverpool
# 4          stephanie.diaz@msm.org  11-06-2018      London
# 5           donald.gump@wahoo.com  11-29-2017   Liverpool
# 6      joe.byethen@whitehouse.gov  12-02-2018     Bristol
# 7       barrack.ohara@jeemail.com  09-11-2018     Belfast
# 8  vladimir.lupin@kremlinmail.com  12-04-2018   Cambridge

# %%
df2=pd.read_csv('df2.csv')

# %%
df2
# Out:
#    Year Pay Raise
# 0  2017        1%
# 1  2018        2%
# 2  2019        3%

# %% [markdown]
# # solving the following questions

# %% [markdown]
# ### Q1) Extract the First and Last Name of each employee based on the email address, which is in the following format:
# ### firstname.lastname@emailprovider.com
# ### firstname - Employee's First Name
# ### lastname - Employee's Last Name

# %%
df01=df0['Email'].str.split('.',n=1,expand=True)

# %%
df01
# Out:
#            0                       1
# 0       john      storm@gotrocks.net
# 1       john       johnson@wahoo.com
# 2      debby      powers@jeemail.com
# 3        joe  byethen@whitehouse.gov
# 4  stephanie            diaz@msm.org
# 5     donald          gump@wahoo.com
# 6      sarah      cohen@coldmail.com
# 7   vladimir   lupin@kremlinmail.com

# %%
df02=df01[1].str.split('@',n=1,expand=True)

# %%
df02.drop([1],axis='columns')
# Out:
#          0
# 0    storm
# 1  johnson
# 2   powers
# 3  byethen
# 4     diaz
# 5     gump
# 6    cohen
# 7    lupin

# %%
df0['First Name']=df01[0]

# %%
df0
# Out:
#                             Email  Employee ID First Name  Last Name  City  \
# 0         john.storm@gotrocks.net         9345       john        NaN   NaN
# 1          john.johnson@wahoo.com         6875       john        NaN   NaN
# 2        debby.powers@jeemail.com         6431      debby        NaN   NaN
# 3      joe.byethen@whitehouse.gov         6076        joe        NaN   NaN
# 4          stephanie.diaz@msm.org         8198  stephanie        NaN   NaN
# 5           donald.gump@wahoo.com         7220     donald        NaN   NaN
# 6        sarah.cohen@coldmail.com         8638      sarah        NaN   NaN
# 7  vladimir.lupin@kremlinmail.com         8187   vladimir        NaN   NaN
#
#    Hire Date  Hiring Year  Payroll  Payroll Raise %  Raise Payroll
# 0        NaN          NaN  £10,088              NaN            NaN
# 1        NaN          NaN  £11,176              NaN            NaN
# 2        NaN          NaN  £10,546              NaN            NaN
# ...

# %%
df0['Last Name']=df02[0]

# %%
df0
# Out:
#                             Email  Employee ID First Name Last Name  City  \
# 0         john.storm@gotrocks.net         9345       john     storm   NaN
# 1          john.johnson@wahoo.com         6875       john   johnson   NaN
# 2        debby.powers@jeemail.com         6431      debby    powers   NaN
# 3      joe.byethen@whitehouse.gov         6076        joe   byethen   NaN
# 4          stephanie.diaz@msm.org         8198  stephanie      diaz   NaN
# 5           donald.gump@wahoo.com         7220     donald      gump   NaN
# 6        sarah.cohen@coldmail.com         8638      sarah     cohen   NaN
# 7  vladimir.lupin@kremlinmail.com         8187   vladimir     lupin   NaN
#
#    Hire Date  Hiring Year  Payroll  Payroll Raise %  Raise Payroll
# 0        NaN          NaN  £10,088              NaN            NaN
# 1        NaN          NaN  £11,176              NaN            NaN
# 2        NaN          NaN  £10,546              NaN            NaN
# ...

# %% [markdown]
# ### Q2) Retrieve the cities where each employee lives from the old system.In case a certain employee isn't found in the old database, it means that he's a new hire, and therefore the default is London.

# %%
df1[['Email','City']]
# Out:
#                             Email        City
# 0          john.johnson@wahoo.com  Manchester
# 1        debby.powers@jeemail.com     Cardiff
# 2        sarah.cohen@coldmail.com  Birmingham
# 3              liza.olson@owl.com   Liverpool
# 4          stephanie.diaz@msm.org      London
# 5           donald.gump@wahoo.com   Liverpool
# 6      joe.byethen@whitehouse.gov     Bristol
# 7       barrack.ohara@jeemail.com     Belfast
# 8  vladimir.lupin@kremlinmail.com   Cambridge

# %%
df0['City']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# Name: City, dtype: float64

# %%
city_1={
    "city_name" :['London','Manchester','Cardiff','Bristol','London','Liverpool','Birmingham','Cambridge'] 
}

# %%
DF=pd.DataFrame(city_1)

# %%
DF
# Out:
#     city_name
# 0      London
# 1  Manchester
# 2     Cardiff
# 3     Bristol
# 4      London
# 5   Liverpool
# 6  Birmingham
# 7   Cambridge

# %%
df0['City']=DF

# %%
df0
# Out:
#                             Email  Employee ID First Name Last Name  \
# 0         john.storm@gotrocks.net         9345       john     storm
# 1          john.johnson@wahoo.com         6875       john   johnson
# 2        debby.powers@jeemail.com         6431      debby    powers
# 3      joe.byethen@whitehouse.gov         6076        joe   byethen
# 4          stephanie.diaz@msm.org         8198  stephanie      diaz
# 5           donald.gump@wahoo.com         7220     donald      gump
# 6        sarah.cohen@coldmail.com         8638      sarah     cohen
# 7  vladimir.lupin@kremlinmail.com         8187   vladimir     lupin
#
#          City  Hire Date  Hiring Year  Payroll  Payroll Raise %  Raise Payroll
# 0      London        NaN          NaN  £10,088              NaN            NaN
# 1  Manchester        NaN          NaN  £11,176              NaN            NaN
# 2     Cardiff        NaN          NaN  £10,546              NaN            NaN
# ...

# %%
df11=df1

# %% [markdown]
# ### Q3) Retrieve the hire date of the employees.In case the hire date is missing, it means that the employee was hired on January 5, 2020.

# %%
df11=df11.drop(df11.index[[3,7]])

# %%
df11
# Out:
#                             Email   Hire date        City
# 0          john.johnson@wahoo.com   1-19-2019  Manchester
# 1        debby.powers@jeemail.com   9-21-2018     Cardiff
# 2        sarah.cohen@coldmail.com  11-16-2018  Birmingham
# 4          stephanie.diaz@msm.org  11-06-2018      London
# 5           donald.gump@wahoo.com  11-29-2017   Liverpool
# 6      joe.byethen@whitehouse.gov  12-02-2018     Bristol
# 8  vladimir.lupin@kremlinmail.com  12-04-2018   Cambridge

# %%
df12 ={
    "Email":["john.storm@gotrocks.net"] ,
    "Hire date": '5-01-2020' ,
    "City":['London'] 
}

# %%
DP=pd.DataFrame(df12)
DP
# Out:
#                      Email  Hire date    City
# 0  john.storm@gotrocks.net  5-01-2020  London

# %%
df0
# Out:
#                             Email  Employee ID First Name Last Name  \
# 0         john.storm@gotrocks.net         9345       john     storm
# 1          john.johnson@wahoo.com         6875       john   johnson
# 2        debby.powers@jeemail.com         6431      debby    powers
# 3      joe.byethen@whitehouse.gov         6076        joe   byethen
# 4          stephanie.diaz@msm.org         8198  stephanie      diaz
# 5           donald.gump@wahoo.com         7220     donald      gump
# 6        sarah.cohen@coldmail.com         8638      sarah     cohen
# 7  vladimir.lupin@kremlinmail.com         8187   vladimir     lupin
#
#          City  Hire Date  Hiring Year  Payroll  Payroll Raise %  Raise Payroll
# 0      London        NaN          NaN  £10,088              NaN            NaN
# 1  Manchester        NaN          NaN  £11,176              NaN            NaN
# 2     Cardiff        NaN          NaN  £10,546              NaN            NaN
# ...

# %%
df11=df11.append(df12, ignore_index=True)

# %%
df11
# Out:
#                             Email   Hire date        City
# 0          john.johnson@wahoo.com   1-19-2019  Manchester
# 1        debby.powers@jeemail.com   9-21-2018     Cardiff
# 2        sarah.cohen@coldmail.com  11-16-2018  Birmingham
# 3          stephanie.diaz@msm.org  11-06-2018      London
# 4           donald.gump@wahoo.com  11-29-2017   Liverpool
# 5      joe.byethen@whitehouse.gov  12-02-2018     Bristol
# 6  vladimir.lupin@kremlinmail.com  12-04-2018   Cambridge
# 7       [john.storm@gotrocks.net]   5-01-2020    [London]

# %%
df13 = df11.reindex([7,0,1,5,3,4,2,6],index=True)

# %%
df13=df13.drop(['Email','City'],axis='columns')

# %%
df13
# Out:
#     Hire date
# 7   5-01-2020
# 0   1-19-2019
# 1   9-21-2018
# 5  12-02-2018
# 3  11-06-2018
# 4  11-29-2017
# 2  11-16-2018
# 6  12-04-2018

# %%
df13=df13.reset_index().drop('index',axis='columns')

# %%
df13
# Out:
#     Hire date
# 0   5-01-2020
# 1   1-19-2019
# 2   9-21-2018
# 3  12-02-2018
# 4  11-06-2018
# 5  11-29-2017
# 6  11-16-2018
# 7  12-04-2018

# %%
df0['Hire Date']=df13

# %%
df0
# Out:
#                             Email  Employee ID First Name Last Name  \
# 0         john.storm@gotrocks.net         9345       john     storm
# 1          john.johnson@wahoo.com         6875       john   johnson
# 2        debby.powers@jeemail.com         6431      debby    powers
# 3      joe.byethen@whitehouse.gov         6076        joe   byethen
# 4          stephanie.diaz@msm.org         8198  stephanie      diaz
# 5           donald.gump@wahoo.com         7220     donald      gump
# 6        sarah.cohen@coldmail.com         8638      sarah     cohen
# 7  vladimir.lupin@kremlinmail.com         8187   vladimir     lupin
#
#          City   Hire Date  Hiring Year  Payroll  Payroll Raise %  \
# 0      London   5-01-2020          NaN  £10,088              NaN
# 1  Manchester   1-19-2019          NaN  £11,176              NaN
# 2     Cardiff   9-21-2018          NaN  £10,546              NaN
# 3     Bristol  12-02-2018          NaN  £10,004              NaN
# ...

# %% [markdown]
# ### Q4) If an employee was hired before 2019, it means he's an experienced employee. Otherwise, return "No experience"

# %%
Df00=df0['Hire Date'].str.split('-',expand=True)

# %%
Df00=Df00.drop([0,1],axis='columns')

# %%
Df00
# Out:
#       2
# 0  2020
# 1  2019
# 2  2018
# 3  2018
# 4  2018
# 5  2017
# 6  2018
# 7  2018

# %%
df0['Hiring Year']=Df00

# %%
df0
# Out:
#                             Email  Employee ID First Name Last Name  \
# 0         john.storm@gotrocks.net         9345       john     storm
# 1          john.johnson@wahoo.com         6875       john   johnson
# 2        debby.powers@jeemail.com         6431      debby    powers
# 3      joe.byethen@whitehouse.gov         6076        joe   byethen
# 4          stephanie.diaz@msm.org         8198  stephanie      diaz
# 5           donald.gump@wahoo.com         7220     donald      gump
# 6        sarah.cohen@coldmail.com         8638      sarah     cohen
# 7  vladimir.lupin@kremlinmail.com         8187   vladimir     lupin
#
#          City   Hire Date Hiring Year  Payroll  Payroll Raise %  Raise Payroll
# 0      London   5-01-2020        2020  £10,088              NaN            NaN
# 1  Manchester   1-19-2019        2019  £11,176              NaN            NaN
# 2     Cardiff   9-21-2018        2018  £10,546              NaN            NaN
# ...

# %%
df01=Df00.replace(['2020','2019','2018','2017'],['No Experince','Experienced','Experienced','Experienced'])

# %%
df01
# Out:
#               2
# 0  No Experince
# 1   Experienced
# 2   Experienced
# 3   Experienced
# 4   Experienced
# 5   Experienced
# 6   Experienced
# 7   Experienced

# %%
df0['years of experince']=df01

# %%
df0
# Out:
#                             Email  Employee ID First Name Last Name  \
# 0         john.storm@gotrocks.net         9345       john     storm
# 1          john.johnson@wahoo.com         6875       john   johnson
# 2        debby.powers@jeemail.com         6431      debby    powers
# 3      joe.byethen@whitehouse.gov         6076        joe   byethen
# 4          stephanie.diaz@msm.org         8198  stephanie      diaz
# 5           donald.gump@wahoo.com         7220     donald      gump
# 6        sarah.cohen@coldmail.com         8638      sarah     cohen
# 7  vladimir.lupin@kremlinmail.com         8187   vladimir     lupin
#
#          City   Hire Date Hiring Year  Payroll  Payroll Raise %  \
# 0      London   5-01-2020        2020  £10,088              NaN
# 1  Manchester   1-19-2019        2019  £11,176              NaN
# 2     Cardiff   9-21-2018        2018  £10,546              NaN
# 3     Bristol  12-02-2018        2018  £10,004              NaN
# ...

# %% [markdown]
# ### Q5) Your company had outstanding financial results in 2020, so the CEO decided to raise the payroll of all the employees in the company, in the following rates:

# %%
df2
# Out:
#    Year Pay Raise
# 0  2017        1%
# 1  2018        2%
# 2  2019        3%

# %%
PF=Df00.replace(['2020','2019','2018','2017'],['0%','3%','2%','1%'])

# %%
PF
# Out:
#     2
# 0  0%
# 1  3%
# 2  2%
# 3  2%
# 4  2%
# 5  1%
# 6  2%
# 7  2%

# %%
df0['Payroll Raise %']= PF

# %%
df0
# Out:
#                             Email  Employee ID First Name Last Name  \
# 0         john.storm@gotrocks.net         9345       john     storm
# 1          john.johnson@wahoo.com         6875       john   johnson
# 2        debby.powers@jeemail.com         6431      debby    powers
# 3      joe.byethen@whitehouse.gov         6076        joe   byethen
# 4          stephanie.diaz@msm.org         8198  stephanie      diaz
# 5           donald.gump@wahoo.com         7220     donald      gump
# 6        sarah.cohen@coldmail.com         8638      sarah     cohen
# 7  vladimir.lupin@kremlinmail.com         8187   vladimir     lupin
#
#          City   Hire Date Hiring Year  Payroll Payroll Raise %  Raise Payroll  \
# 0      London   5-01-2020        2020  £10,088              0%            NaN
# 1  Manchester   1-19-2019        2019  £11,176              3%            NaN
# 2     Cardiff   9-21-2018        2018  £10,546              2%            NaN
# ...

# %%
AF1=df0['Payroll'].str.replace('£','').str.replace(',','')

# %%
AF1=pd.to_numeric(AF1)

# %%
AF1
# Out:
# 0    10088
# 1    11176
# 2    10546
# 3    10004
# 4    11383
# 5    10236
# 6    10822
# 7    11379
# Name: Payroll, dtype: int64

# %%
AF=AF1

# %%
AF
# Out:
# 0    10088
# 1    11176
# 2    10546
# 3    10004
# 4    11383
# 5    10236
# 6    10822
# 7    11379
# Name: Payroll, dtype: int64

# %%
GF=df0['Payroll Raise %'].str.split('%',n=1,expand=True).drop([1],axis='columns')

# %%
GF=GF.astype('int64')

# %%
GF['payroll']=GF

# %%
GF['payroll']= AF

# %%
GF
# Out:
#    0  payroll
# 0  0    10088
# 1  3    11176
# 2  2    10546
# 3  2    10004
# 4  2    11383
# 5  1    10236
# 6  2    10822
# 7  2    11379

# %%
GF
# Out:
#    0  payroll
# 0  0    10088
# 1  3    11176
# 2  2    10546
# 3  2    10004
# 4  2    11383
# 5  1    10236
# 6  2    10822
# 7  2    11379

# %%
GF['Raised']=GF.apply(lambda row: row['payroll'] + (row[0]*row['payroll'])/100, axis='columns')

# %%
GF
# Out:
#    0  payroll    Raised
# 0  0    10088  10088.00
# 1  3    11176  11511.28
# 2  2    10546  10756.92
# 3  2    10004  10204.08
# 4  2    11383  11610.66
# 5  1    10236  10338.36
# 6  2    10822  11038.44
# 7  2    11379  11606.58

# %%
df0['Raise Payroll']=GF['Raised']

# %%
df0
# Out:
#                             Email  Employee ID First Name Last Name  \
# 0         john.storm@gotrocks.net         9345       john     storm
# 1          john.johnson@wahoo.com         6875       john   johnson
# 2        debby.powers@jeemail.com         6431      debby    powers
# 3      joe.byethen@whitehouse.gov         6076        joe   byethen
# 4          stephanie.diaz@msm.org         8198  stephanie      diaz
# 5           donald.gump@wahoo.com         7220     donald      gump
# 6        sarah.cohen@coldmail.com         8638      sarah     cohen
# 7  vladimir.lupin@kremlinmail.com         8187   vladimir     lupin
#
#          City   Hire Date Hiring Year  Payroll Payroll Raise %  Raise Payroll  \
# 0      London   5-01-2020        2020  £10,088              0%       10088.00
# 1  Manchester   1-19-2019        2019  £11,176              3%       11511.28
# 2     Cardiff   9-21-2018        2018  £10,546              2%       10756.92
# ...

# %% [markdown]
# ### This is the obtained final data after preprocessing
